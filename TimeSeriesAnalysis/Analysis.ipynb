# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
import datetime as dt

# %%
df1=pd.read_csv('AirPassengers.csv')
df1.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
df1.dtypes
# Out:
# Month          object
# #Passengers     int64
# dtype: object

# %%
df1=pd.read_csv('AirPassengers.csv',parse_dates=['Month'],dayfirst=True)

# %%
df1.dtypes
# Out:
# Month          datetime64[ns]
# #Passengers             int64
# dtype: object

# %%
df1.head()
# Out:
#        Month  #Passengers
# 0 1949-01-01          112
# 1 1949-02-01          118
# 2 1949-03-01          132
# 3 1949-04-01          129
# 4 1949-05-01          121

# %%
df1=pd.read_csv('AirPassengers.csv',parse_dates=['Month'],dayfirst=True,index_col='Month')

# %%
df1.head()
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %%
df1['1949-01-01':'1949-12-01']
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121
# 1949-06-01          135
# 1949-07-01          148
# 1949-08-01          148
# 1949-09-01          136
# 1949-10-01          119
# 1949-11-01          104
# 1949-12-01          118

# %%
df1.loc['1949-5-01']
# Out:
# #Passengers    121
# Name: 1949-05-01 00:00:00, dtype: int64

# %%
plt.figure(figsize=(20,12))
df1.plot()
plt.show()

# %%
from pylab import rcParams
rcParams['figure.figsize']=(20,12)
df1.plot()
plt.show()

# %%
df1_mul_decompose=seasonal_decompose(df1,model='multiplicative')
df1_mul_decompose.plot()
plt.show()

# %%
df1_log=df1.copy()

# %%
df1_log['#Passengers']=np.log(df1)

# %%
df1_log.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
plt.subplot(2,1,1)
df1.plot()
plt.subplot(2,1,2)
df1_log.plot()
plt.show()
